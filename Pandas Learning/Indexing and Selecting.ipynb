# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# # REVIEW THE BASICS

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# get columns
tips[['total_bill', "smoker"]].head()
# Out:
#    total_bill smoker
# 0       16.99     No
# 1       10.34     No
# 2       21.01     No
# 3       23.68     No
# 4       24.59     No

# %%
# get columns
tips["smoker"].head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: smoker, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
# get tows
tips[3:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# get rows amd columns based on their name
tips.loc[2:4, "sex":"smoker"]
# Out:
#       sex smoker
# 2    Male     No
# 3    Male     No
# 4  Female     No

# %%
# get rows amd columns by their ordering
tips.iloc[1:3, 0:2]
# Out:
#    total_bill   tip
# 1       10.34  1.66
# 2       21.01  3.50

# %%
# select using a bool series
tips[tips["tip"] > 3].head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 7       26.88  3.12    Male     No  Sun  Dinner     4

# %% [markdown]
# # MULTI-INDEX

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.groupby(["sex", "smoker"]).agg({"tip":"median"})
# Out:
#                 tip
# sex    smoker
# Male   Yes     3.00
#        No      2.74
# Female Yes     2.88
#        No      2.68

# %%
tips.groupby(["sex", "smoker", "day"]).agg({"tip":"mean"})
# Out:
#                          tip
# sex    smoker day
# Male   Yes    Thur  3.058000
#               Fri   2.741250
#               Sat   2.879259
#               Sun   3.521333
#        No     Thur  2.941500
#               Fri   2.500000
#               Sat   3.256563
#               Sun   3.115349
# Female Yes    Thur  2.990000
#               Fri   2.682857
#               Sat   2.868667
#               Sun   3.500000
#        No     Thur  2.459600
#               Fri   3.125000
#               Sat   2.724615
#               Sun   3.329286

# %%
mi_tips = tips.groupby(["sex", "smoker"]).agg({"tip":"mean"})
mi_tips
# Out:
#                     tip
# sex    smoker
# Male   Yes     3.051167
#        No      3.113402
# Female Yes     2.931515
#        No      2.773519

# %%
mi_tips.index
# Out:
# MultiIndex([(  'Male', 'Yes'),
#             (  'Male',  'No'),
#             ('Female', 'Yes'),
#             ('Female',  'No')],
#            names=['sex', 'smoker'])

# %%
mi_tips.loc[("Male", "No")]
# Out:
# tip    3.113402
# Name: (Male, No), dtype: float64

# %%
mi_tips.loc["Male", "No"]
# Out:
# tip    3.113402
# Name: (Male, No), dtype: float64

# %%
ri_tips = mi_tips.reset_index()
ri_tips
# Out:
#       sex smoker       tip
# 0    Male    Yes  3.051167
# 1    Male     No  3.113402
# 2  Female    Yes  2.931515
# 3  Female     No  2.773519

# %%
# The same way to choose male non-smokers
ri_tips[(ri_tips["smoker"] == "No") & (ri_tips["sex"] == "Male")]
# Out:
#     sex smoker       tip
# 1  Male     No  3.113402

# %%
mi_tips.reset_index(level=0)
# Out:
#            sex       tip
# smoker
# Yes       Male  3.051167
# No        Male  3.113402
# Yes     Female  2.931515
# No      Female  2.773519

# %%
mi_tips.reset_index(level=1).loc["Male"]
# Out:
#      smoker       tip
# sex
# Male    Yes  3.051167
# Male     No  3.113402

# %%
ri0_tips = mi_tips.reset_index(level=0)
ri0_tips.loc["Yes"]
# Out:
#            sex       tip
# smoker
# Yes       Male  3.051167
# Yes     Female  2.931515

# %%
ri_tips.set_index(["sex"])
# Out:
#        smoker       tip
# sex
# Male      Yes  3.051167
# Male       No  3.113402
# Female    Yes  2.931515
# Female     No  2.773519

# %%
ri_tips.set_index(["sex", "smoker"])
# Out:
#                     tip
# sex    smoker
# Male   Yes     3.051167
#        No      3.113402
# Female Yes     2.931515
#        No      2.773519

# %%
ri_tips.set_index("sex", append=True)
# Out:
#          smoker       tip
#   sex
# 0 Male      Yes  3.051167
# 1 Male       No  3.113402
# 2 Female    Yes  2.931515
# 3 Female     No  2.773519

# %% [markdown]
# # GETTING SINGLE VALUES

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
# Using at is much faster than loc
tips.at[0, "total_bill"] = 9000
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0     9000.00  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips.iat[0, 0]
# Out:
# 9000.0

# %% [markdown]
# # WHERE, MASKS, QUERIES

# %%
# These things are faster than what was described prevously

# %%
df = pd.DataFrame(np.random.randn(25).reshape(5,5))
df.head()
# Out:
#           0         1         2         3         4
# 0  0.522885 -1.131639  1.422782  0.435936  1.359763
# 1  2.138247  1.516577 -0.622137  1.349703 -1.198687
# 2 -2.051206  0.555670  0.208896  0.520529 -0.982192
# 3 -0.946580 -0.421818  0.488550  0.901477  0.572710
# 4  0.377493  1.435266  0.698575 -0.271132  1.840246

# %%
df.where(df > 0)
# Out:
#           0         1         2         3         4
# 0  0.522885       NaN  1.422782  0.435936  1.359763
# 1  2.138247  1.516577       NaN  1.349703       NaN
# 2       NaN  0.555670  0.208896  0.520529       NaN
# 3       NaN       NaN  0.488550  0.901477  0.572710
# 4  0.377493  1.435266  0.698575       NaN  1.840246

# %%
df[df < 0] = np.NaN
df
# Out:
#           0         1         2         3         4
# 0  0.522885       NaN  1.422782  0.435936  1.359763
# 1  2.138247  1.516577       NaN  1.349703       NaN
# 2       NaN  0.555670  0.208896  0.520529       NaN
# 3       NaN       NaN  0.488550  0.901477  0.572710
# 4  0.377493  1.435266  0.698575       NaN  1.840246
